# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("valakhorasani/bank-transaction-dataset-for-fraud-detection")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('bank_transactions_data_2.csv')
df
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0         TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1         TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2         TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3         TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4         TX000005   AC00411              13.45  2023-10-16 17:51:24
# ...            ...       ...                ...                  ...
# 2507      TX002508   AC00297             856.21  2023-04-26 17:09:36
# 2508      TX002509   AC00322             251.54  2023-03-22 17:36:48
# 2509      TX002510   AC00095              28.63  2023-08-21 17:08:50
# 2510      TX002511   AC00118             185.97  2023-02-24 16:24:46
# 2511      TX002512   AC00009             243.08  2023-02-14 16:21:23
#
#      TransactionType          Location DeviceID      IP Address MerchantID  \
# ...

# %%
#df.sort_values(by='AccountID', ascending=True)
#df[df['LoginAttempts'] > 1]
#df.pivot_table(index=['AccountID','TransactionID'], values='TransactionAmount', aggfunc='sum')
#df.sort_values(by='TransactionDate', ascending=False)['TransactionID'] == 'TX000687'

df[df['AccountID'] == 'AC00370'].sort_values(by='TransactionDate', ascending=False)
#df[(df['LoginAttempts'] >= 2)].sort_values(by = 'LoginAttempts', ascending=False)
#df[(df['LoginAttempts'] >= 2)].sort_values(by = 'AccountID', ascending=False)
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 686       TX000687   AC00370             280.92  2024-01-01 18:21:50
# 849       TX000850   AC00370             194.99  2023-12-01 17:01:30
# 2400      TX002401   AC00370             131.69  2023-10-16 16:22:32
# 625       TX000626   AC00370             821.54  2023-08-22 18:11:16
# 1501      TX001502   AC00370             417.26  2023-02-27 17:01:24
# 1964      TX001965   AC00370              78.93  2023-02-17 16:41:31
# 207       TX000208   AC00370             485.54  2023-02-06 17:46:59
#
#      TransactionType      Location DeviceID       IP Address MerchantID  \
# 686            Debit       Phoenix  D000320    120.170.93.69       M048
# 849            Debit  Jacksonville  D000442  173.232.121.213       M097
# 2400          Credit        Denver  D000044   30.229.179.194       M067
# 625           Credit       Atlanta  D000142   19.111.192.175       M044
# ...

# %%
df[(df['LoginAttempts'] >= 2)].sort_values(by = 'AccountID', ascending=False).head(15)
#should focus primarily for debit transactions since WHO THE FUCK WOULD CREDIT AN ACCOUNT AND CONSIDER IT FRAUD WAHAH TNGA
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 117       TX000118   AC00498              56.98  2024-01-01 16:34:10
# 414       TX000415   AC00495              83.50  2023-05-15 18:47:35
# 38        TX000039   AC00478             795.31  2023-10-12 17:07:40
# 1309      TX001310   AC00470             470.96  2023-03-10 16:22:05
# 792       TX000793   AC00468             253.55  2023-01-11 16:56:58
# 2371      TX002372   AC00465              21.23  2023-09-11 16:35:15
# 551       TX000552   AC00465             106.16  2023-04-14 17:21:48
# 1161      TX001162   AC00460             484.30  2023-10-17 17:46:52
# 547       TX000548   AC00456              97.09  2023-04-10 18:26:56
# 1659      TX001660   AC00456              53.79  2023-12-05 16:01:44
# 274       TX000275   AC00454            1176.28  2023-12-20 16:08:02
# 23        TX000024   AC00453             345.84  2023-05-02 18:25:46
# 476       TX000477   AC00442              53.81  2023-10-16 16:55:44
# ...
